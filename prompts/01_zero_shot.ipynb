# %% [markdown]
# # Промпт #01 — Zero-shot classification
#
# **Техника:** Zero-shot
# **Задача:** Классифицировать отзыв как позитивный или негативный
# **Сложность:** ⭐☆☆☆☆

# %%
import sys
sys.path.append('..')
from config import get_completion

# %%
review = "Этот ноутбук работает быстро, батарея держит долго, очень доволен покупкой!"

prompt = f"""Классифицируй отзыв как ПОЗИТИВНЫЙ или НЕГАТИВНЫЙ.
Отвечай одним словом.

Отзыв: {review}"""

result = get_completion(prompt)
print(result)
# Out:
# ПОЗИТИВНЫЙ

# %% [markdown]
# ## Оценка: 5/5
#
# ## Инсайт
# Zero-shot отлично справляется с простой классификацией.
# Модель следует инструкции и отвечает одним словом без лишнего текста.
